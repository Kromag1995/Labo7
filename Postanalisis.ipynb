# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
f = open('./post_analisis/Complejidades.txt')
Complejidades = f.read()

# %%
comp = {}
for linea in Complejidades.split('\n')[1:]:
    l = linea.split(";")
    comp[l[0]] = {"media": l[2], "mediana": l[3]}
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-7d270038f56d> in <module>
#       2 for linea in Complejidades.split('\n')[1:]:
#       3     l = linea.split(";")
# ----> 4     comp[l[0]] = {"media": l[2], "mediana": l[3]}
#
# IndexError: list index out of range

# %%
llaves_ordenadas = sorted(comp)
llaves_v = llaves_ordenadas[::2]
llaves_t = llaves_ordenadas[1::2]

# %%
frecuencia = [250,230,210,190,170, 150]

# %%
for i in range(len(llaves_t)):
    plt.plot(frecuencia[i//10],float(comp[llaves_t[i]]["media"]), "r.")
    plt.plot(frecuencia[i//10],float(comp[llaves_t[i]]["mediana"]), "b.")
plt.plot(frecuencia[i//10],float(comp[llaves_t[i]]["media"]), "r.", label="Media")
plt.plot(frecuencia[i//10],float(comp[llaves_t[i]]["mediana"]), "b.", label="Mediana")
plt.plot(frecuencia, 0.5*np.ones(len(frecuencia)), 'k-.')
plt.legend(loc='best')
plt.grid()
plt.title("Series t")
plt.xticks(frecuencia,frecuencia[:-1]+["170 ancho 2.5"])
plt.ylabel("complejidad(ua)")
plt.xlabel("frecuencia(kHz)")
plt.savefig("series_t.png")

# %%
for i in range(len(llaves_v)):
    plt.plot(frecuencia[i//10],float(comp[llaves_v[i]]["media"]), "r.")
    plt.plot(frecuencia[i//10],float(comp[llaves_v[i]]["mediana"]), "b.")
plt.plot(frecuencia[i//10],float(comp[llaves_v[i]]["media"]), "r.", label="Media")
plt.plot(frecuencia[i//10],float(comp[llaves_v[i]]["mediana"]), "b.", label="Mediana")
plt.plot(frecuencia, 0.5*np.ones(len(frecuencia)), 'k-.')
plt.legend(loc='best')
plt.title("Series V")
plt.grid()
plt.xticks(frecuencia,frecuencia[:-1]+["170 ancho 2.5"])
plt.ylabel("complejidad(ua)")
plt.xlabel("frecuencia(kHz)")
plt.savefig("series_v.png")
plt.show()

# %%
for i in range(len(llaves_v)):
    plt.plot(frecuencia[i//10],float(comp[llaves_v[i]]["media"]), "r.")
    plt.plot(frecuencia[i//10],float(comp[llaves_v[i]]["mediana"]), "b.")
plt.plot(frecuencia[i//10],float(comp[llaves_v[i]]["media"]), "r.", label="Media V")
plt.plot(frecuencia[i//10],float(comp[llaves_v[i]]["mediana"]), "b.", label="Mediana V")
plt.plot(frecuencia, 0.5*np.ones(len(frecuencia)), 'k-.')
plt.legend(loc='best')
plt.title("Series V")
plt.ylabel("complejidad(ua)")
plt.xlabel("frecuencia(kHz)")
#plt.savefig("series_v.png")
for i in range(len(llaves_t)):
    plt.plot(frecuencia[i//10],float(comp[llaves_t[i]]["media"]), "g.")
    plt.plot(frecuencia[i//10],float(comp[llaves_t[i]]["mediana"]), "y.")
plt.plot(frecuencia[i//10],float(comp[llaves_t[i]]["media"]), "g.", label="Media t")
plt.plot(frecuencia[i//10],float(comp[llaves_t[i]]["mediana"]), "y.", label="Mediana t")
plt.plot(frecuencia, 0.5*np.ones(len(frecuencia)), 'k-.')
plt.legend(loc='best')
plt.grid()
plt.title("Series V y t")
plt.ylabel("complejidad(ua)")
plt.xlabel("frecuencia(kHz)")
#plt.savefig("series_t.png")
# Out:
# Text(0.5, 0, 'frecuencia(kHz)')

# %%
f = open('./post_analisis/resultados.csv')
resultados_nists = f.read()

# %%
sr = resultados_nists.split('\n')[1:]

# %%
sr = {}
for linea in resultados_nists.split('\n')[1:]:
    l = linea.split(";")
    for ll in l:
        
        comp[l[0]] = {"media": l[2], "mediana": l[3]}
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-74-ae152753b821> in <module>
#       3 for linea in Complejidades.split('\n')[1:]:
#       4     l = linea.split(";")
# ----> 5     comp[l[0]] = {"media": l[2], "mediana": l[3]}
#
# IndexError: list index out of range

# %%
resultados_nists.split('\n')[1].split(';')
# Out:
# ['20210407-0011_02_V_mediana32228.bin',
#  '(0.0020288256445599416, False)',
#  '(2.332597283015248e-41, False)',
#  '(1.383432168064562e-141, False)',
#  '(2.4506124317050623e-36, False)',
#  '(0.1806806601895186, True)',
#  '(5.090866545395254e-13, False)',
#  '(1.62458626691383e-232, False)',
#  '(1.2681786981019952e-16, False)',
#  '(-1.0, False)',
#  '(0.5235056044647066, True)',
#  '((0.0, False), (3.2777527458657256e-23, False))',
#  '(0.0, False)',
#  '(0.0038353958817589117, False)',
#  '(8.632283915722473e-06, False)',
#  "[('-4', -4, 9.9323198667222, 0.07717580373205443, True), ('-3', -3, 9.05885, 0.10673972765123659, True), ('-2', -2, 1.6628086419753083, 0.8935515199810684, True), ('-1', -1, 3.34375, 0.6471505260171622, True), ('+1', 1, 6.78125, 0.2374239509672987, True), ('+2', 2, 14.53317901234568, 0.012554809298581174, True), ('+3', 3, 11.97215, 0.035171388992780536, True), ('+4', 4, 41.03285089546023, 9.240494337198813e-08, False)]",
# ...
